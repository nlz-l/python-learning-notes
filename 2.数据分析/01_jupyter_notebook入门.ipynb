# %% [markdown]
# # Jupyter Notebook 入门

# %%
# 命令模式常用快捷键: A -> 新建cell并上方, B -> 新建cell并下方, DD -> 删除cell, M -> 切换为markdown, Y -> 切换为代码

# %%
# 通用模式常用快捷键: Ctrl + Enter -> 执行当前cell, Shift + Enter -> 执行当前cell并新建cell

# %% [markdown]
# # Markdown 写法

# %% [markdown]
# # 一级标题
# ## 二级标题
# ### 三级标题
# #### 四级标题
# ##### 五级标题
# ###### 六级标题
# - 一级缩进
#     - 二级缩进
#         - 三级缩进
